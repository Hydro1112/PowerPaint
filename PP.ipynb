# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd /content/gdrive/MyDrive/KLTN/PowerPaint
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/MyDrive/KLTN/PowerPaint

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# %cd /content/gdrive/MyDrive/KLTN/PowerPaint
import os
with open(".env") as f:
    for line in f:
        k, _, v = line.strip().partition("=")
        if k:
            os.environ.setdefault(k, v)
assert os.getenv("NGROK_AUTHTOKEN"), "NGROK_AUTHTOKEN not found in .env"
# Out:
# /content/gdrive/MyDrive/KLTN/PowerPaint

# %%
# !conda env create -f requirements/ppt.yml
# Out:
# done
# Channels:
#  - defaults
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.11.0
#     latest version: 26.7.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ...
# python-3.10.11       | 26.8 MB   | :   0% 0/1 [00:00<?, ?it/s]
# libgcc-ng-11.2.0     | 5.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
# openssl-3.0.14       | 5.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# libstdcxx-ng-11.2.0  | 4.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# git-lfs-3.5.1        | 4.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# tk-8.6.14            | 3.4 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# sqlite-3.45.3        | 1.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# setuptools-83.0.0    | 1.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# pip-26.1.2           | 1.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# ...

# %%
# !conda run -n ppt pip install pyngrok
# Out:
# ...
#
# ***REDACTED***

# %%
# !conda run -n ppt --no-capture-output bash -c "export MPLBACKEND=Agg && export NGROK_AUTHTOKEN=$NGROK_AUTHTOKEN && python app.py --ngrok --version ppt-v2 --checkpoint_dir checkpoints/ppt-v2"
# Out:
# /usr/local/envs/ppt/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# diffusion_pytorch_model.safetensors: 100% 3.44G/3.44G [00:25<00:00, 116MB/s]
# config.json: 100% 617/617 [00:00<00:00, 6.16MB/s]
# model.safetensors: 100% 492M/492M [00:07<00:00, 64.2MB/s]
# Loading pipeline components...:  50% 3/6 [00:40<00:44, 14.88s/it]/usr/local/envs/ppt/lib/python3.10/site-packages/transformers/models/clip/feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(
# Loading pipeline components...: 100% 6/6 [01:33<00:00, 15.59s/it]
# ...
