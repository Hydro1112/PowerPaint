# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd /content/gdrive/MyDrive/FE_KLTN/PowerPaint
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/FE_KLTN/PowerPaint

# %%
# !pip install -q condacolab
import condacolab
import os
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/25.11.0-1/Miniforge3-25.11.0-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:09
# 🔁 Restarting kernel...

# %%
# %cd /content/gdrive/MyDrive/FE_KLTN/PowerPaint
# Out:
# /content/gdrive/MyDrive/FE_KLTN/PowerPaint

# %%
# !conda env remove -n ppt -y 2>/dev/null; PIP_EXTRA_INDEX_URL=https://download.pytorch.org/whl/cu118 conda env create -f requirements/ppt.yml
# Out:
# done
# Channels:
#  - defaults
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.11.0
#     latest version: 26.7.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ...
# python-3.10.11       | 26.8 MB   | :   0% 0/1 [00:00<?, ?it/s]
# libgcc-ng-11.2.0     | 5.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
# openssl-3.0.14       | 5.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# libstdcxx-ng-11.2.0  | 4.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# git-lfs-3.5.1        | 4.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# tk-8.6.14            | 3.4 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# pip-24.0             | 2.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# sqlite-3.45.3        | 1.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# setuptools-69.5.1    | 1012 KB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# ...

# %%
# !conda run -n ppt --no-capture-output bash -c "export MPLBACKEND=Agg && python app.py --share --version ppt-v2 --checkpoint_dir checkpoints/ppt-v2"
# Out:
# /usr/local/envs/ppt/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json: 100% 743/743 [00:00<00:00, 5.99MB/s]
# ...
